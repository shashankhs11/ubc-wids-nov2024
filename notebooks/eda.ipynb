# %%
import pandas as pd
import numpy as np
import re
from textblob import TextBlob
from nltk.corpus import stopwords

# %%
train_df = pd.read_csv('../input/train.csv')
test_df = pd.read_csv('../input/test.csv')
train_df.set_index('id', inplace=True)
train_df.head()
# Out:
#                      Unnamed: 0  \
# id
# 19792418                    879
# 1015650685503221866        6416
# 35265562                   1820
# 911948980885194155         5346
# 46069251                   2484
#
#                                                                   name  \
# id
# 19792418             Home in Vancouver · ★4.75 · 1 bedroom · 1 bed ...
# 1015650685503221866  Guest suite in Vancouver · ★New · 2 bedrooms ·...
# 35265562             Guest suite in Vancouver · ★4.85 · 2 bedrooms ...
# 911948980885194155   Home in Vancouver · ★5.0 · 1 bedroom · 1 bed ·...
# 46069251             Guest suite in Vancouver · ★4.93 · 1 bedroom ·...
#
#                                                  neighborhood_overview  \
# id
# 19792418             Everything you need is nearby. <br /><br />Hig...
# 1015650685503221866                                                NaN
# 35265562             Beautiful neighbourhood close to prosperous Ma...
# 911948980885194155   We are located in a quiet residential neighbor...
# 46069251             Kitsilano at it's best! Short walk to all the ...
#
#                        host_id host_name  host_response_time  \
# id
# 19792418              57488206     Jessi                 NaN
# 1015650685503221866  139792573    Daniel  within a few hours
# 35265562             265504225      Alex      within an hour
# 911948980885194155    22595056   Raymond                 NaN
# 46069251              65683877     Yendi      within an hour
#
#                     host_response_rate host_acceptance_rate host_is_superhost  \
# id
# 19792418                           NaN                  NaN                 f
# 1015650685503221866               100%                 100%                 f
# 35265562                          100%                  98%                 t
# 911948980885194155                 NaN                  92%                 t
# 46069251                          100%                  95%                 t
#
#                      host_listings_count  ...  review_scores_accuracy  \
# id                                        ...
# 19792418                               3  ...                    4.80
# 1015650685503221866                    1  ...                     NaN
# 35265562                               1  ...                    4.90
# 911948980885194155                     1  ...                    5.00
# 46069251                               2  ...                    4.93
#
#                     review_scores_cleanliness review_scores_checkin  \
# id
# 19792418                                 4.82                  4.90
# 1015650685503221866                       NaN                   NaN
# 35265562                                 4.78                  4.97
# 911948980885194155                       5.00                  5.00
# 46069251                                 4.89                  4.97
#
#                      review_scores_communication  review_scores_location  \
# id
# 19792418                                    4.87                    4.69
# 1015650685503221866                          NaN                     NaN
# 35265562                                    4.94                    4.90
# 911948980885194155                          5.00                    4.86
# 46069251                                    4.97                    4.96
#
#                     review_scores_value instant_bookable  \
# id
# 19792418                           4.81                f
# 1015650685503221866                 NaN                f
# 35265562                           4.75                f
# 911948980885194155                 5.00                f
# 46069251                           4.85                f
#
#                      calculated_host_listings_count  reviews_per_month  \
# id
# 19792418                                          3               0.77
# 1015650685503221866                               1                NaN
# 35265562                                          1               3.22
# 911948980885194155                                1               1.28
# 46069251                                          1               2.01
#
#                      monthly_revenue
# id
# 19792418                        2108
# 1015650685503221866             2730
# 35265562                        2254
# 911948980885194155              3187
# 46069251                        3479
#
# [5 rows x 44 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5352 entries, 19792418 to 19298482
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      5352 non-null   int64
#  1   name                            5352 non-null   object
#  2   neighborhood_overview           3476 non-null   object
#  3   host_id                         5352 non-null   int64
#  4   host_name                       5352 non-null   object
#  5   host_response_time              4263 non-null   object
#  6   host_response_rate              4263 non-null   object
#  7   host_acceptance_rate            4620 non-null   object
#  8   host_is_superhost               5315 non-null   object
#  9   host_listings_count             5352 non-null   int64
#  10  host_total_listings_count       5352 non-null   int64
#  11  neighbourhood                   3476 non-null   object
#  12  neighbourhood_cleansed          5352 non-null   object
#  13  latitude                        5352 non-null   float64
#  14  longitude                       5352 non-null   float64
#  15  property_type                   5352 non-null   object
#  16  room_type                       5352 non-null   object
#  17  accommodates                    5352 non-null   int64
#  18  bathrooms                       0 non-null      float64
#  19  bedrooms                        0 non-null      float64
#  20  beds                            5316 non-null   float64
#  21  amenities                       5352 non-null   object
#  22  price                           4687 non-null   object
#  23  minimum_nights                  5352 non-null   int64
#  24  maximum_nights                  5352 non-null   int64
#  25  minimum_nights_avg_ntm          5352 non-null   float64
#  26  maximum_nights_avg_ntm          5352 non-null   float64
#  27  availability_30                 5352 non-null   int64
#  28  availability_60                 5352 non-null   int64
#  29  availability_90                 5352 non-null   int64
#  30  availability_365                5352 non-null   int64
#  31  number_of_reviews               5352 non-null   int64
#  32  number_of_reviews_ltm           5352 non-null   int64
#  33  review_scores_rating            4452 non-null   float64
#  34  review_scores_accuracy          4452 non-null   float64
#  35  review_scores_cleanliness       4452 non-null   float64
#  36  review_scores_checkin           4451 non-null   float64
#  37  review_scores_communication     4452 non-null   float64
#  38  review_scores_location          4451 non-null   float64
#  39  review_scores_value             4451 non-null   float64
#  40  instant_bookable                5352 non-null   object
#  41  calculated_host_listings_count  5352 non-null   int64
#  42  reviews_per_month               4446 non-null   float64
#  43  monthly_revenue                 5352 non-null   int64
# dtypes: float64(15), int64(15), object(14)
# memory usage: 1.8+ MB

# %%
train_df.drop(train_df.columns[0], axis=1, inplace=True)
train_df.drop('bathrooms', axis=1, inplace=True)
train_df.drop('bedrooms', axis=1, inplace=True)

# %%
missing_values = train_df.isnull().sum()
print(missing_values[missing_values > 0].sort_values(ascending=False))  # Columns with missing data
# Out:
# neighborhood_overview          1876
# neighbourhood                  1876
# host_response_time             1089
# host_response_rate             1089
# reviews_per_month               906
# review_scores_checkin           901
# review_scores_location          901
# review_scores_value             901
# review_scores_rating            900
# review_scores_accuracy          900
# review_scores_cleanliness       900
# review_scores_communication     900
# host_acceptance_rate            732
# price                           665
# host_is_superhost                37
# beds                             36
# dtype: int64

# %%
train_df.columns
# Out:
# Index(['name', 'neighborhood_overview', 'host_id', 'host_name',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_listings_count', 'host_total_listings_count',
#        'neighbourhood', 'neighbourhood_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'beds', 'amenities',
#        'price', 'minimum_nights', 'maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'number_of_reviews_ltm', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'instant_bookable',
#        'calculated_host_listings_count', 'reviews_per_month',
#        'monthly_revenue'],
#       dtype='object')

# %%
train_df['neighbourhood_cleansed'].value_counts()
# Out:
# neighbourhood_cleansed
# Downtown                    1389
# West End                     411
# Kitsilano                    381
# Mount Pleasant               353
# Kensington-Cedar Cottage     326
# Downtown Eastside            299
# Riley Park                   250
# Grandview-Woodland           217
# Hastings-Sunrise             216
# Renfrew-Collingwood          190
# Dunbar Southlands            171
# Marpole                      158
# Fairview                     144
# Sunset                       143
# Victoria-Fraserview          128
# Oakridge                     107
# West Point Grey              105
# Arbutus Ridge                 87
# Kerrisdale                    68
# Killarney                     65
# Shaughnessy                   63
# South Cambie                  54
# Strathcona                    27
# Name: count, dtype: int64

# %%
for idx, i in enumerate(train_df['name']):
# for idx, i in enumerate(train_df['neighborhood_overview']):
    print(i)
    if idx == 5:
        break
# Out:
# Home in Vancouver · ★4.75 · 1 bedroom · 1 bed · 1 bath
# Guest suite in Vancouver · ★New · 2 bedrooms · 2 beds · 1 bath
# Guest suite in Vancouver · ★4.85 · 2 bedrooms · 3 beds · 1 bath
# Home in Vancouver · ★5.0 · 1 bedroom · 1 bed · 1 bath
# Guest suite in Vancouver · ★4.93 · 1 bedroom · 2 beds · 1 bath
# Condo in Vancouver · ★4.88 · Studio · 1 bed · 1 bath

# %%
# Regex patterns for extraction
property_type_pattern = r"^(.*?) in Vancouver"
rating_pattern = r"★([0-9.]+|New)"
bedrooms_pattern = r"(\d+) bedroom"
beds_pattern = r"(\d+) bed"
baths_pattern = r"(\d+) bath"

# Functions to extract each feature
def extract_property_type(name):
    match = re.search(property_type_pattern, name)
    return match.group(1) if match else None

def extract_rating(name):
    match = re.search(rating_pattern, name)
    return float(match.group(1)) if match and match.group(1).replace('.', '', 1).isdigit() else None

def extract_bedrooms(name):
    match = re.search(bedrooms_pattern, name)
    return int(match.group(1)) if match else (0 if 'Studio' in name else None)

def extract_beds(name):
    match = re.search(beds_pattern, name)
    return int(match.group(1)) if match else None

def extract_baths(name):
    match = re.search(baths_pattern, name)
    return int(match.group(1)) if match else None

# Apply functions to extract features
train_df['property_type'] = train_df['name'].apply(extract_property_type)
train_df['rating'] = train_df['name'].apply(extract_rating)
train_df['bedrooms'] = train_df['name'].apply(extract_bedrooms)
train_df['beds'] = train_df['name'].apply(extract_beds)
train_df['baths'] = train_df['name'].apply(extract_baths)

# Fill missing ratings for "New" as a separate indicator
train_df['is_new_listing'] = train_df['rating'].isnull().astype(int)
train_df['rating'] = train_df['rating'].fillna(0)  # Optional: set "New" ratings to 0 or another placeholder

# Show resulting DataFrame
train_df.head()
# Out:
#                                                                   name  \
# id
# 19792418             Home in Vancouver · ★4.75 · 1 bedroom · 1 bed ...
# 1015650685503221866  Guest suite in Vancouver · ★New · 2 bedrooms ·...
# 35265562             Guest suite in Vancouver · ★4.85 · 2 bedrooms ...
# 911948980885194155   Home in Vancouver · ★5.0 · 1 bedroom · 1 bed ·...
# 46069251             Guest suite in Vancouver · ★4.93 · 1 bedroom ·...
#
#                                                  neighborhood_overview  \
# id
# 19792418             Everything you need is nearby. <br /><br />Hig...
# 1015650685503221866                                                NaN
# 35265562             Beautiful neighbourhood close to prosperous Ma...
# 911948980885194155   We are located in a quiet residential neighbor...
# 46069251             Kitsilano at it's best! Short walk to all the ...
#
#                        host_id host_name  host_response_time  \
# id
# 19792418              57488206     Jessi                 NaN
# 1015650685503221866  139792573    Daniel  within a few hours
# 35265562             265504225      Alex      within an hour
# 911948980885194155    22595056   Raymond                 NaN
# 46069251              65683877     Yendi      within an hour
#
#                     host_response_rate host_acceptance_rate host_is_superhost  \
# id
# 19792418                           NaN                  NaN                 f
# 1015650685503221866               100%                 100%                 f
# 35265562                          100%                  98%                 t
# 911948980885194155                 NaN                  92%                 t
# 46069251                          100%                  95%                 t
#
#                      host_listings_count  host_total_listings_count  ...  \
# id                                                                   ...
# 19792418                               3                          3  ...
# 1015650685503221866                    1                          4  ...
# 35265562                               1                          1  ...
# 911948980885194155                     1                          1  ...
# 46069251                               2                          3  ...
#
#                     review_scores_location review_scores_value  \
# id
# 19792418                              4.69                4.81
# 1015650685503221866                    NaN                 NaN
# 35265562                              4.90                4.75
# 911948980885194155                    4.86                5.00
# 46069251                              4.96                4.85
#
#                      instant_bookable  calculated_host_listings_count  \
# id
# 19792418                            f                               3
# 1015650685503221866                 f                               1
# 35265562                            f                               1
# 911948980885194155                  f                               1
# 46069251                            f                               1
#
#                     reviews_per_month monthly_revenue  rating  bedrooms baths  \
# id
# 19792418                         0.77            2108    4.75       1.0   1.0
# 1015650685503221866               NaN            2730    0.00       2.0   1.0
# 35265562                         3.22            2254    4.85       2.0   1.0
# 911948980885194155               1.28            3187    5.00       1.0   1.0
# 46069251                         2.01            3479    4.93       1.0   1.0
#
#                     is_new_listing
# id
# 19792418                         0
# 1015650685503221866              1
# 35265562                         0
# 911948980885194155               0
# 46069251                         0
#
# [5 rows x 45 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5352 entries, 19792418 to 19298482
# Data columns (total 45 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            5352 non-null   object
#  1   neighborhood_overview           3476 non-null   object
#  2   host_id                         5352 non-null   int64
#  3   host_name                       5352 non-null   object
#  4   host_response_time              4263 non-null   object
#  5   host_response_rate              4263 non-null   object
#  6   host_acceptance_rate            4620 non-null   object
#  7   host_is_superhost               5315 non-null   object
#  8   host_listings_count             5352 non-null   int64
#  9   host_total_listings_count       5352 non-null   int64
#  10  neighbourhood                   3476 non-null   object
#  11  neighbourhood_cleansed          5352 non-null   object
#  12  latitude                        5352 non-null   float64
#  13  longitude                       5352 non-null   float64
#  14  property_type                   5341 non-null   object
#  15  room_type                       5352 non-null   object
#  16  accommodates                    5352 non-null   int64
#  17  beds                            5346 non-null   float64
#  18  amenities                       5352 non-null   object
#  19  price                           4687 non-null   object
#  20  minimum_nights                  5352 non-null   int64
#  21  maximum_nights                  5352 non-null   int64
#  22  minimum_nights_avg_ntm          5352 non-null   float64
#  23  maximum_nights_avg_ntm          5352 non-null   float64
#  24  availability_30                 5352 non-null   int64
#  25  availability_60                 5352 non-null   int64
#  26  availability_90                 5352 non-null   int64
#  27  availability_365                5352 non-null   int64
#  28  number_of_reviews               5352 non-null   int64
#  29  number_of_reviews_ltm           5352 non-null   int64
#  30  review_scores_rating            4452 non-null   float64
#  31  review_scores_accuracy          4452 non-null   float64
#  32  review_scores_cleanliness       4452 non-null   float64
#  33  review_scores_checkin           4451 non-null   float64
#  34  review_scores_communication     4452 non-null   float64
#  35  review_scores_location          4451 non-null   float64
#  36  review_scores_value             4451 non-null   float64
#  37  instant_bookable                5352 non-null   object
#  38  calculated_host_listings_count  5352 non-null   int64
#  39  reviews_per_month               4446 non-null   float64
#  40  monthly_revenue                 5352 non-null   int64
#  41  rating                          5352 non-null   float64
#  42  bedrooms                        5349 non-null   float64
#  43  baths                           4523 non-null   float64
#  44  is_new_listing                  5352 non-null   int64
# dtypes: float64(16), int64(15), object(14)
# memory usage: 1.9+ MB

# %%
# Clean up HTML tags and fill NaN values
train_df['neighborhood_overview'] = train_df['neighborhood_overview'].fillna("No description provided")
train_df['neighborhood_overview'] = train_df['neighborhood_overview'].apply(lambda x: re.sub(r'<.*?>', '', str(x)))

# Keyword presence feature extraction
def has_keyword(text, keyword):
    return int(bool(re.search(r'\b' + keyword + r'\b', text.lower())))

# Apply keyword search for various categories
keywords = ['park', 'restaurant', 'shopping', 'beach', 'quiet', 'transit', 'lively', 'trendy']
for keyword in keywords:
    train_df[f'has_{keyword}'] = train_df['neighborhood_overview'].apply(lambda x: has_keyword(x, keyword))

# Sentiment Analysis
train_df['polarity'] = train_df['neighborhood_overview'].apply(lambda x: TextBlob(x).sentiment.polarity)
train_df['subjectivity'] = train_df['neighborhood_overview'].apply(lambda x: TextBlob(x).sentiment.subjectivity)

# Text Length
train_df['review_length'] = train_df['neighborhood_overview'].apply(lambda x: len(x.split()))

# Show resulting DataFrame
train_df.head()
# Out:
#                                                                   name  \
# id
# 19792418             Home in Vancouver · ★4.75 · 1 bedroom · 1 bed ...
# 1015650685503221866  Guest suite in Vancouver · ★New · 2 bedrooms ·...
# 35265562             Guest suite in Vancouver · ★4.85 · 2 bedrooms ...
# 911948980885194155   Home in Vancouver · ★5.0 · 1 bedroom · 1 bed ·...
# 46069251             Guest suite in Vancouver · ★4.93 · 1 bedroom ·...
#
#                                                  neighborhood_overview  \
# id
# 19792418             Everything you need is nearby. Highlight: Walk...
# 1015650685503221866                            No description provided
# 35265562             Beautiful neighbourhood close to prosperous Ma...
# 911948980885194155   We are located in a quiet residential neighbor...
# 46069251             Kitsilano at it's best! Short walk to all the ...
#
#                        host_id host_name  host_response_time  \
# id
# 19792418              57488206     Jessi                 NaN
# 1015650685503221866  139792573    Daniel  within a few hours
# 35265562             265504225      Alex      within an hour
# 911948980885194155    22595056   Raymond                 NaN
# 46069251              65683877     Yendi      within an hour
#
#                     host_response_rate host_acceptance_rate host_is_superhost  \
# id
# 19792418                           NaN                  NaN                 f
# 1015650685503221866               100%                 100%                 f
# 35265562                          100%                  98%                 t
# 911948980885194155                 NaN                  92%                 t
# 46069251                          100%                  95%                 t
#
#                      host_listings_count  host_total_listings_count  ...  \
# id                                                                   ...
# 19792418                               3                          3  ...
# 1015650685503221866                    1                          4  ...
# 35265562                               1                          1  ...
# 911948980885194155                     1                          1  ...
# 46069251                               2                          3  ...
#
#                     has_restaurant has_shopping  has_beach  has_quiet  \
# id
# 19792418                         0            0          0          0
# 1015650685503221866              0            0          0          0
# 35265562                         0            1          0          0
# 911948980885194155               0            0          0          1
# 46069251                         0            0          0          0
#
#                     has_transit has_lively  has_trendy  polarity subjectivity  \
# id
# 19792418                      0          0           0  0.217857     0.621429
# 1015650685503221866           0          0           0  0.000000     0.000000
# 35265562                      0          0           0  0.108974     0.292308
# 911948980885194155            0          0           0  0.258333     0.791667
# 46069251                      1          0           0  0.333333     0.200000
#
#                     review_length
# id
# 19792418                       91
# 1015650685503221866             3
# 35265562                      124
# 911948980885194155             52
# 46069251                       51
#
# [5 rows x 56 columns]
